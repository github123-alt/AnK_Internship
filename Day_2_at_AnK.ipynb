# %% [markdown]
# <a href="https://colab.research.google.com/github/github123-alt/AnK_Internship_requirement/blob/main/Day_2_at_AnK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %% [markdown]
# # **1. Example Task**

# %%
df = pd.read_csv('/population.csv')

# %%
x = df['Year']
y= df['Population']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train.values.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test.values.reshape(-1, 1))

# %%
#Evaluation of model using appropriate metrics

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

# %%
display(mse)
display(r2)
display(mae)
# Out:
# 4.346492181183489e+17
# 0.0014967194365902436
# 323737102.6858883

# %% [markdown]
# # **2. Minor Project**

# %%
data = pd.read_csv('/student_income_score.csv')

# %%
print(data.head())
print(data.info())
data = data.dropna()
# Out:
#    Hours    Income  Score
# 0   0.95       NaN  20.93
# 1   2.04  19656.02  38.62
# 2   2.82  30366.18  60.40
# 3   4.08  39520.58  81.88
# 4   5.13  49712.34  98.73
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   29 non-null     float64
#  1   Income  29 non-null     float64
#  2   Score   30 non-null     float64
# dtypes: float64(3)
# memory usage: 852.0 bytes
# None

# %%
x = data[['Hours','Income']]
y = data['Score']

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error:", mae)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Absolute Error: 1.5930238271286428
# Mean Squared Error: 2.7607450044009227
# R-squared: 0.9961461494749951

# %%
results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
print(results)
# Out:
#     Actual  Predicted
# 10   18.26  20.119989
# 26   41.45  39.661678
# 9    98.19  99.703006
# 22   58.30  60.635535
# 1    38.62  39.789289
# 13   79.98  79.087998

# %%
plt.scatter( y_test, y_pred, color='blue', label='Actual vs predicted')

min_val = min(y_test.min(), y_pred.min())
max_val = max(y_test.max(), y_pred.max())
line = np.linspace(min_val, max_val, 100)
plt.plot(line, line, color='red', label='Regression Line')

plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted Scores')
plt.grid(True)
plt.legend()
plt.show()
